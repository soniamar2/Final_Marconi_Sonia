# %% [markdown]
# # Seaborn
# it is an extention of mathplotlib. which means it benefits from the flexibility of matplotlib, but also inherits the verbosity of matplotlib.
# - Pros: Built on Matplotlib with enhanced aesthetics; efficient for statistical plots.
# - Cons: Less customizable than Matplotlib; might not be suitable for advanced or non-statistical plots.

# %% [markdown]
# needs anaconda or pip install Seabourn in command line.
#
# than need to import, import seaborn as sns

# %%
#let's start with matplotlib
from matplotlib import pyplot as plt
x = [10,20,30,40]
y = [0,15,10,25]
plt.plot(x,y)

# %%
# seaborn updates matplotlib to improve aesthetics
import seaborn as sns

# %%
sns.set()
#deprecated, non prende di default questi valori ma posso farlo manualmente

# %%
#manualmente
sns.set_style("whitegrid")
sns.set_context("notebook")
sns.set_palette("deep")
#sns.set_color_codes("True")
#sns.set_rc("None")
#sns.set_font("sans-serif")
#sns.set_font_scale("1")
plt.plot(x,y)
# the default is now better

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.4'

# %%
sns.__version__
# Out:
# '0.13.2'

# %% [markdown]
# # Seaborn and Matplotlib
# So how seaborn updates matplotlib:
# seaborn actually updates matplotlib rc (run commands) parameters. these are default parameters that are inizialized when we make a new figure. Example: background color, grid color, font size etc. So, Seaborn is built aboive matplotlib code but provides additional functionality, often times better syntax and oftentimes better defaults . But it is inheriting a lot of the code from matplotlib that means that we can continue to use a lot of the matplotlib code in order to update our Seaborn figures.
#
# Seaborn’s integration with matplotlib allows you to use it across the many environments that matplotlib supports, including exploratory analysis in notebooks, real-time interaction in GUI applications, and archival output in a number of raster and vector formats.
#
# While you can be productive using only seaborn functions, full customization of your graphics will require some knowledge of matplotlib’s concepts and API. One aspect of the learning curve for new users of seaborn will be knowing when dropping down to the matplotlib layer is necessary to achieve a particular customization. On the other hand, users coming from matplotlib will find that much of their knowledge transfers.
#
# Matplotlib has a comprehensive and powerful API; just about any attribute of the figure can be changed to your liking. A combination of seaborn’s high-level interface and matplotlib’s deep customizability will allow you both to quickly explore your data and to create graphics that can be tailored into a publication quality final product.

# %% [markdown]
# # Seaborn and Pandas
# another good things of seaborn is how easily it integrates with pandas. Seaborn can group our data, aggregate it, and plot it alll from our pandas dataframe. I can pass in sns directly the pandas dataframe, example sns.replot(..., data= cars). Quindi posso dargli tutto il dataframe di pandas e poi lasciare che sia seaborn stessa a splittare il dataset per come ci serve. Esempio: sns.replot(x='model_year", y='mpg', col='origin', hue='cylinders', data=cars)
# it creates a separate column for each origin of my dataset. it is also doing the shading of each of those dots based on the number of cylinders that each car has. So seaborn integrates really well with pandas.

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme() #to set the default theme I was talking about before

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %% [markdown]
# There is no universally best way to visualize data. Different questions are best answered by different plots. Seaborn makes it easy to switch between different visual representations by using a consistent dataset-oriented API.
#
# The function relplot() is named that way because it is designed to visualize many different statistical relationships. While scatter plots are often effective, relationships where one variable represents a measure of time are better represented by a line. The relplot() function has a convenient kind parameter that lets you easily switch to this alternate representation:

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %% [markdown]
# Many seaborn functions will automatically perform the statistical estimation

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %% [markdown]
# When statistical values are estimated, seaborn will use bootstrapping to compute confidence intervals and draw error bars representing the uncertainty of the estimate.
#
# Statistical estimation in seaborn goes beyond descriptive statistics. For example, it is possible to enhance a scatterplot by including a linear regression model (and its uncertainty) using lmplot():

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %% [markdown]
# Also, seaborn can provide distributional representation, plots of categorical data. Moreover, some seaborn functions combine multiple kinds of plots to quickly give informative summaries of a dataset. Seaborn creates complete graphics with a single function call: when possible, its functions will automatically add informative axis labels and legends that explain the semantic mappings in the plot.
#
# In many cases, seaborn will also choose default values for its parameters based on characteristics of the data. For example, the color mappings that we have seen so far used distinct hues (blue, orange, and sometimes green) to represent different levels of the categorical variables assigned to hue.
